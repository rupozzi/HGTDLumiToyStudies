# %%
import ROOT
import numpy as np
import time as time

# Count the time
start_time = time.time()

# Load the file and get the tree
f = ROOT.TFile.Open("SiHitValid_s3654.root", "READ")
tree = f.Get("SiHGTD")
print("The loaded tree 'hgtdHits' contains %d events" % tree.GetEntries())

# Print out the objects and branches
f.ls()
tree.Print()  

# Create histograms
histo_hits = ROOT.TH1F("Hits histo", "HGTD hits vs eta; |eta|; Number of hits", 50, 2.39, 2.81) 
histo_per_interaction = ROOT.TH1F("Hits per event", "HGTD hits for %d interactions; Number of hits; Frequency"%tree.GetEntries(), 50, 0., 1100.) 

eventCount = 0
printDetailsEventMax=100

# Number of hits that fall inside the acceptance conditions
hits_per_interaction = np.zeros(100)

# Loop through each event in the tree
for event in tree:
    
    printEventDetails = (eventCount < printDetailsEventMax) 
    print("eventCount = %d, printEventDetails = %s" % (eventCount, str(printEventDetails)))
    
    hits_count = 0
    if printEventDetails:
        print("--->Number of HGTD hits: %d" % len(event.HGTD_x)) 
        print ("Looping through all the Hits...")
        # For each event, loop threough every hit and check acceptance conditions
        for h in range (len(event.HGTD_x)):
            r = event.HGTD_r[h] #radial coordinate of the hit 
            z = event.HGTD_z[h] #zeta coordinate (along beamline) of the hit
            eta = -np.log((r/z)/2) 
            if abs(eta) > 2.4 and abs(eta) < 2.8: #acceptance on the detector 
                hits_count += 1
                histo_hits.Fill(eta)
                
        
    print("Hits inside acceptance: %d"%hits_count)
    hits_per_interaction[eventCount]= hits_count
    
    eventCount += 1 

# Calculate the CPU time
hours, rem = divmod(time.time()-start_time, 3600)
minutes, seconds = divmod(rem, 60)
print("Computation done!\nCPU time: %d hours, %d minutes and %d seconds" %(hours, minutes,seconds))
# Out:
# The loaded tree 'hgtdHits' contains 100 events
# eventCount = 0, printEventDetails = True
# --->Number of HGTD hits: 1564
# Looping through all the Hits...
# Hits inside acceptance: 214
# eventCount = 1, printEventDetails = True
# --->Number of HGTD hits: 1470
# Looping through all the Hits...
# Hits inside acceptance: 167
# eventCount = 2, printEventDetails = True
# --->Number of HGTD hits: 2679
# Looping through all the Hits...
# Hits inside acceptance: 474
# eventCount = 3, printEventDetails = True
# --->Number of HGTD hits: 1257
# Looping through all the Hits...
# Hits inside acceptance: 244
# eventCount = 4, printEventDetails = True
# --->Number of HGTD hits: 2243
# Looping through all the Hits...
# Hits inside acceptance: 181
# eventCount = 5, printEventDetails = True
# --->Number of HGTD hits: 2046
# Looping through all the Hits...
# Hits inside acceptance: 184
# eventCount = 6, printEventDetails = True
# --->Number of HGTD hits: 2512
# Looping through all the Hits...
# Hits inside acceptance: 332
# eventCount = 7, printEventDetails = True
# --->Number of HGTD hits: 2298
# Looping through all the Hits...
# Hits inside acceptance: 114
# eventCount = 8, printEventDetails = True
# --->Number of HGTD hits: 1464
# Looping through all the Hits...
# Hits inside acceptance: 275
# eventCount = 9, printEventDetails = True
# --->Number of HGTD hits: 1531
# Looping through all the Hits...
# Hits inside acceptance: 149
# eventCount = 10, printEventDetails = True
# --->Number of HGTD hits: 1133
# Looping through all the Hits...
# Hits inside acceptance: 88
# eventCount = 11, printEventDetails = True
# --->Number of HGTD hits: 702
# Looping through all the Hits...
# Hits inside acceptance: 49
# eventCount = 12, printEventDetails = True
# --->Number of HGTD hits: 3323
# Looping through all the Hits...
# Hits inside acceptance: 515
# eventCount = 13, printEventDetails = True
# --->Number of HGTD hits: 966
# Looping through all the Hits...
# Hits inside acceptance: 204
# eventCount = 14, printEventDetails = True
# --->Number of HGTD hits: 1428
# Looping through all the Hits...
# Hits inside acceptance: 205
# eventCount = 15, printEventDetails = True
# --->Number of HGTD hits: 3766
# Looping through all the Hits...
# Hits inside acceptance: 452
# eventCount = 16, printEventDetails = True
# --->Number of HGTD hits: 1967
# Looping through all the Hits...
# Hits inside acceptance: 410
# eventCount = 17, printEventDetails = True
# --->Number of HGTD hits: 1788
# Looping through all the Hits...
# Hits inside acceptance: 150
# eventCount = 18, printEventDetails = True
# --->Number of HGTD hits: 4385
# Looping through all the Hits...
# Hits inside acceptance: 730
# eventCount = 19, printEventDetails = True
# --->Number of HGTD hits: 2851
# Looping through all the Hits...
# Hits inside acceptance: 437
# eventCount = 20, printEventDetails = True
# --->Number of HGTD hits: 2254
# Looping through all the Hits...
# Hits inside acceptance: 251
# eventCount = 21, printEventDetails = True
# --->Number of HGTD hits: 2957
# Looping through all the Hits...
# <ipython-input-21-faa033909cc8>:41: RuntimeWarning: invalid value encountered in log
#   eta = -np.log((r/z)/2)
# Hits inside acceptance: 247
# eventCount = 22, printEventDetails = True
# --->Number of HGTD hits: 2373
# Looping through all the Hits...
# Hits inside acceptance: 406
# eventCount = 23, printEventDetails = True
# --->Number of HGTD hits: 1557
# Looping through all the Hits...
# Hits inside acceptance: 307
# eventCount = 24, printEventDetails = True
# --->Number of HGTD hits: 2025
# Looping through all the Hits...
# Hits inside acceptance: 236
# eventCount = 25, printEventDetails = True
# --->Number of HGTD hits: 1510
# Looping through all the Hits...
# Hits inside acceptance: 220
# eventCount = 26, printEventDetails = True
# --->Number of HGTD hits: 2893
# Looping through all the Hits...
# Hits inside acceptance: 360
# eventCount = 27, printEventDetails = True
# --->Number of HGTD hits: 1417
# Looping through all the Hits...
# Hits inside acceptance: 434
# eventCount = 28, printEventDetails = True
# --->Number of HGTD hits: 3389
# Looping through all the Hits...
# Hits inside acceptance: 1017
# eventCount = 29, printEventDetails = True
# --->Number of HGTD hits: 1188
# Looping through all the Hits...
# Hits inside acceptance: 181
# eventCount = 30, printEventDetails = True
# --->Number of HGTD hits: 4360
# Looping through all the Hits...
# Hits inside acceptance: 426
# eventCount = 31, printEventDetails = True
# --->Number of HGTD hits: 3313
# Looping through all the Hits...
# Hits inside acceptance: 379
# eventCount = 32, printEventDetails = True
# --->Number of HGTD hits: 918
# Looping through all the Hits...
# Hits inside acceptance: 129
# eventCount = 33, printEventDetails = True
# --->Number of HGTD hits: 1217
# Looping through all the Hits...
# Hits inside acceptance: 237
# eventCount = 34, printEventDetails = True
# --->Number of HGTD hits: 3386
# Looping through all the Hits...
# Hits inside acceptance: 813
# eventCount = 35, printEventDetails = True
# --->Number of HGTD hits: 1297
# Looping through all the Hits...
# Hits inside acceptance: 204
# eventCount = 36, printEventDetails = True
# --->Number of HGTD hits: 2129
# Looping through all the Hits...
# Hits inside acceptance: 321
# eventCount = 37, printEventDetails = True
# --->Number of HGTD hits: 2257
# Looping through all the Hits...
# Hits inside acceptance: 438
# eventCount = 38, printEventDetails = True
# --->Number of HGTD hits: 3302
# Looping through all the Hits...
# Hits inside acceptance: 510
# eventCount = 39, printEventDetails = True
# --->Number of HGTD hits: 2470
# Looping through all the Hits...
# Hits inside acceptance: 349
# eventCount = 40, printEventDetails = True
# --->Number of HGTD hits: 1546
# Looping through all the Hits...
# Hits inside acceptance: 116
# eventCount = 41, printEventDetails = True
# --->Number of HGTD hits: 442
# Looping through all the Hits...
# Hits inside acceptance: 59
# eventCount = 42, printEventDetails = True
# --->Number of HGTD hits: 1781
# Looping through all the Hits...
# Hits inside acceptance: 186
# eventCount = 43, printEventDetails = True
# --->Number of HGTD hits: 2059
# Looping through all the Hits...
# Hits inside acceptance: 252
# eventCount = 44, printEventDetails = True
# --->Number of HGTD hits: 2737
# Looping through all the Hits...
# Hits inside acceptance: 340
# eventCount = 45, printEventDetails = True
# --->Number of HGTD hits: 610
# Looping through all the Hits...
# Hits inside acceptance: 29
# eventCount = 46, printEventDetails = True
# --->Number of HGTD hits: 3168
# Looping through all the Hits...
# Hits inside acceptance: 299
# eventCount = 47, printEventDetails = True
# --->Number of HGTD hits: 1787
# Looping through all the Hits...
# Hits inside acceptance: 193
# eventCount = 48, printEventDetails = True
# --->Number of HGTD hits: 1013
# Looping through all the Hits...
# Hits inside acceptance: 11
# eventCount = 49, printEventDetails = True
# --->Number of HGTD hits: 2298
# Looping through all the Hits...
# Hits inside acceptance: 347
# eventCount = 50, printEventDetails = True
# --->Number of HGTD hits: 795
# Looping through all the Hits...
# Hits inside acceptance: 118
# eventCount = 51, printEventDetails = True
# --->Number of HGTD hits: 1886
# Looping through all the Hits...
# Hits inside acceptance: 261
# eventCount = 52, printEventDetails = True
# --->Number of HGTD hits: 1129
# Looping through all the Hits...
# Hits inside acceptance: 100
# eventCount = 53, printEventDetails = True
# --->Number of HGTD hits: 2909
# Looping through all the Hits...
# Hits inside acceptance: 258
# eventCount = 54, printEventDetails = True
# --->Number of HGTD hits: 1149
# Looping through all the Hits...
# Hits inside acceptance: 62
# eventCount = 55, printEventDetails = True
# --->Number of HGTD hits: 2950
# Looping through all the Hits...
# Hits inside acceptance: 1075
# eventCount = 56, printEventDetails = True
# --->Number of HGTD hits: 581
# Looping through all the Hits...
# Hits inside acceptance: 151
# eventCount = 57, printEventDetails = True
# --->Number of HGTD hits: 1497
# Looping through all the Hits...
# Hits inside acceptance: 135
# eventCount = 58, printEventDetails = True
# --->Number of HGTD hits: 2050
# Looping through all the Hits...
# Hits inside acceptance: 268
# eventCount = 59, printEventDetails = True
# --->Number of HGTD hits: 1206
# Looping through all the Hits...
# Hits inside acceptance: 183
# eventCount = 60, printEventDetails = True
# --->Number of HGTD hits: 2936
# Looping through all the Hits...
# Hits inside acceptance: 408
# eventCount = 61, printEventDetails = True
# --->Number of HGTD hits: 2555
# Looping through all the Hits...
# Hits inside acceptance: 208
# eventCount = 62, printEventDetails = True
# --->Number of HGTD hits: 3205
# Looping through all the Hits...
# Hits inside acceptance: 103
# eventCount = 63, printEventDetails = True
# --->Number of HGTD hits: 1691
# Looping through all the Hits...
# Hits inside acceptance: 26
# eventCount = 64, printEventDetails = True
# --->Number of HGTD hits: 2216
# Looping through all the Hits...
# Hits inside acceptance: 249
# eventCount = 65, printEventDetails = True
# --->Number of HGTD hits: 2775
# Looping through all the Hits...
# Hits inside acceptance: 382
# eventCount = 66, printEventDetails = True
# --->Number of HGTD hits: 4115
# Looping through all the Hits...
# Hits inside acceptance: 357
# eventCount = 67, printEventDetails = True
# --->Number of HGTD hits: 2608
# Looping through all the Hits...
# Hits inside acceptance: 415
# eventCount = 68, printEventDetails = True
# --->Number of HGTD hits: 2566
# Looping through all the Hits...
# Hits inside acceptance: 216
# eventCount = 69, printEventDetails = True
# --->Number of HGTD hits: 2961
# Looping through all the Hits...
# Hits inside acceptance: 447
# eventCount = 70, printEventDetails = True
# --->Number of HGTD hits: 1880
# Looping through all the Hits...
# Hits inside acceptance: 159
# eventCount = 71, printEventDetails = True
# --->Number of HGTD hits: 2464
# Looping through all the Hits...
# Hits inside acceptance: 510
# eventCount = 72, printEventDetails = True
# --->Number of HGTD hits: 2502
# Looping through all the Hits...
# Hits inside acceptance: 292
# eventCount = 73, printEventDetails = True
# --->Number of HGTD hits: 3246
# Looping through all the Hits...
# Hits inside acceptance: 452
# eventCount = 74, printEventDetails = True
# --->Number of HGTD hits: 2345
# Looping through all the Hits...
# Hits inside acceptance: 285
# eventCount = 75, printEventDetails = True
# --->Number of HGTD hits: 2305
# Looping through all the Hits...
# Hits inside acceptance: 740
# eventCount = 76, printEventDetails = True
# --->Number of HGTD hits: 1959
# Looping through all the Hits...
# Hits inside acceptance: 248
# eventCount = 77, printEventDetails = True
# --->Number of HGTD hits: 709
# Looping through all the Hits...
# Hits inside acceptance: 129
# eventCount = 78, printEventDetails = True
# --->Number of HGTD hits: 739
# Looping through all the Hits...
# Hits inside acceptance: 65
# eventCount = 79, printEventDetails = True
# --->Number of HGTD hits: 1649
# Looping through all the Hits...
# Hits inside acceptance: 279
# eventCount = 80, printEventDetails = True
# --->Number of HGTD hits: 3212
# Looping through all the Hits...
# Hits inside acceptance: 549
# eventCount = 81, printEventDetails = True
# --->Number of HGTD hits: 790
# Looping through all the Hits...
# Hits inside acceptance: 37
# eventCount = 82, printEventDetails = True
# --->Number of HGTD hits: 1404
# Looping through all the Hits...
# Hits inside acceptance: 153
# eventCount = 83, printEventDetails = True
# --->Number of HGTD hits: 1288
# Looping through all the Hits...
# Hits inside acceptance: 7
# eventCount = 84, printEventDetails = True
# --->Number of HGTD hits: 2398
# Looping through all the Hits...
# Hits inside acceptance: 462
# eventCount = 85, printEventDetails = True
# --->Number of HGTD hits: 2845
# Looping through all the Hits...
# Hits inside acceptance: 160
# eventCount = 86, printEventDetails = True
# --->Number of HGTD hits: 2333
# Looping through all the Hits...
# Hits inside acceptance: 133
# eventCount = 87, printEventDetails = True
# --->Number of HGTD hits: 1201
# Looping through all the Hits...
# Hits inside acceptance: 80
# eventCount = 88, printEventDetails = True
# --->Number of HGTD hits: 1611
# Looping through all the Hits...
# Hits inside acceptance: 237
# eventCount = 89, printEventDetails = True
# --->Number of HGTD hits: 2530
# Looping through all the Hits...
# Hits inside acceptance: 396
# eventCount = 90, printEventDetails = True
# --->Number of HGTD hits: 2577
# Looping through all the Hits...
# Hits inside acceptance: 316
# eventCount = 91, printEventDetails = True
# --->Number of HGTD hits: 5147
# Looping through all the Hits...
# Hits inside acceptance: 542
# eventCount = 92, printEventDetails = True
# --->Number of HGTD hits: 2413
# Looping through all the Hits...
# Hits inside acceptance: 483
# eventCount = 93, printEventDetails = True
# --->Number of HGTD hits: 1273
# Looping through all the Hits...
# Hits inside acceptance: 90
# eventCount = 94, printEventDetails = True
# --->Number of HGTD hits: 1501
# Looping through all the Hits...
# Hits inside acceptance: 81
# eventCount = 95, printEventDetails = True
# --->Number of HGTD hits: 2909
# Looping through all the Hits...
# Hits inside acceptance: 716
# eventCount = 96, printEventDetails = True
# --->Number of HGTD hits: 4148
# Looping through all the Hits...
# Hits inside acceptance: 263
# eventCount = 97, printEventDetails = True
# --->Number of HGTD hits: 2778
# Looping through all the Hits...
# Hits inside acceptance: 458
# eventCount = 98, printEventDetails = True
# --->Number of HGTD hits: 740
# Looping through all the Hits...
# Hits inside acceptance: 98
# eventCount = 99, printEventDetails = True
# --->Number of HGTD hits: 3022
# Looping through all the Hits...
# Hits inside acceptance: 392
# Computation done!
# CPU time: 0 hours, 0 minutes and 1 seconds
# TFile**		SiHitValid_s3654.root
#  TFile*		SiHitValid_s3654.root
#   OBJ: TTree	SiHGTD	SiHGTD : 0 at: 0x87102f0
#   KEY: TH1D	h_Pixel_x;1	h_Pixel_x
#   KEY: TH1D	h_Pixel_y;1	h_Pixel_y
#   KEY: TH1D	h_Pixel_z;1	h_Pixel_z
#   KEY: TH1D	h_Pixel_r;1	h_Pixel_r
#   KEY: TH2D	h_Pixel_xy;1	h_Pixel_xy
#   KEY: TH2D	h_Pixel_zr;1	h_Pixel_zr
#   KEY: TH1D	h_Pixel_time;1	h_Pixel_time
#   KEY: TH1D	h_Pixel_eloss;1	h_Pixel_eloss
#   KEY: TH1D	h_Pixel_step;1	h_Pixel_step
#   KEY: TH1D	h_Pixel_barcode;1	h_Pixel_barcode
#   KEY: TTree	SiPixel;1	SiPixel
#   KEY: TH1D	h_SCT_x;1	h_SCT_x
#   KEY: TH1D	h_SCT_y;1	h_SCT_y
#   KEY: TH1D	h_SCT_z;1	h_SCT_z
#   KEY: TH1D	h_SCT_r;1	h_SCT_r
#   KEY: TH2D	h_SCT_xy;1	h_SCT_xy
#   KEY: TH2D	h_SCT_zr;1	h_SCT_zr
#   KEY: TH1D	h_SCT_time;1	h_SCT_time
#   KEY: TH1D	h_SCT_eloss;1	h_SCT_eloss
#   KEY: TH1D	h_SCT_step;1	h_SCT_step
#   KEY: TH1D	h_SCT_barcode;1	h_SCT_barcode
#   KEY: TTree	SiSCT;1	SiSCT
#   KEY: TH1D	h_HGTD_x;1	h_HGTD_x
#   KEY: TH1D	h_HGTD_y;1	h_HGTD_y
#   KEY: TH1D	h_HGTD_z;1	h_HGTD_z
#   KEY: TH1D	h_HGTD_r;1	h_HGTD_r
#   KEY: TH2D	h_HGTD_xy;1	h_HGTD_xy
#   KEY: TH2D	h_HGTD_zr;1	h_HGTD_zr
#   KEY: TH1D	h_HGTD_time;1	h_HGTD_time
#   KEY: TH1D	h_HGTD_eloss;1	h_HGTD_eloss
#   KEY: TH1D	h_HGTD_step;1	h_HGTD_step
#   KEY: TH1D	h_HGTD_barcode;1	h_HGTD_barcode
#   KEY: TTree	SiHGTD;1	SiHGTD
# ******************************************************************************
# *Tree    :SiHGTD    : SiHGTD                                                 *
# *Entries :      100 : Total =         6910057 bytes  File  Size =    4494995 *
# *        :          : Tree compression factor =   1.54                       *
# ******************************************************************************
# *Br    0 :HGTD_x    : vector<float>                                          *
# *Entries :      100 : Total  Size=     863596 bytes  File Size  =     759937 *
# *Baskets :       29 : Basket Size=      32000 bytes  Compression=   1.14     *
# *............................................................................*
# *Br    1 :HGTD_y    : vector<float>                                          *
# *Entries :      100 : Total  Size=     863596 bytes  File Size  =     758416 *
# *Baskets :       29 : Basket Size=      32000 bytes  Compression=   1.14     *
# *............................................................................*
# *Br    2 :HGTD_z    : vector<float>                                          *
# *Entries :      100 : Total  Size=     863596 bytes  File Size  =     266240 *
# *Baskets :       29 : Basket Size=      32000 bytes  Compression=   3.24     *
# *............................................................................*
# *Br    3 :HGTD_r    : vector<float>                                          *
# *Entries :      100 : Total  Size=     863596 bytes  File Size  =     716120 *
# *Baskets :       29 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br    4 :HGTD_time : vector<float>                                          *
# *Entries :      100 : Total  Size=     863695 bytes  File Size  =     624256 *
# *Baskets :       29 : Basket Size=      32000 bytes  Compression=   1.38     *
# *............................................................................*
# *Br    5 :HGTD_eloss : vector<float>                                         *
# *Entries :      100 : Total  Size=     863728 bytes  File Size  =     583425 *
# *Baskets :       29 : Basket Size=      32000 bytes  Compression=   1.48     *
# *............................................................................*
# *Br    6 :HGTD_step : vector<float>                                          *
# *Entries :      100 : Total  Size=     863695 bytes  File Size  =     710150 *
# *Baskets :       29 : Basket Size=      32000 bytes  Compression=   1.21     *
# *............................................................................*
# *Br    7 :HGTD_barcode : vector<float>                                       *
# *Entries :      100 : Total  Size=     863794 bytes  File Size  =      73649 *
# *Baskets :       29 : Basket Size=      32000 bytes  Compression=  11.72     *
# *............................................................................*

# %%
# open a canvas to draw the histogram on
c1 = ROOT.TCanvas("Canvas", "Title", 800, 600)
# draw the histogram
histo_hits.Draw() # draw option "e1" will draw error bars
# open the canvas
c1.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas

# %%
print (hits_per_interaction)

# Fill the histogram with the acceptance hits for each interaction
for i in range (len(hits_per_interaction)):
    histo_per_interaction.Fill(hits_per_interaction[i])

# Plot the histogram
c1 = ROOT.TCanvas("Canvas", "Title", 800, 600)
histo_per_interaction.Draw() 
c1.Draw()
# Out:
# [ 214.  167.  474.  244.  181.  184.  332.  114.  275.  149.   88.   49.
#   515.  204.  205.  452.  410.  150.  730.  437.  251.  247.  406.  307.
#   236.  220.  360.  434. 1017.  181.  426.  379.  129.  237.  813.  204.
#   321.  438.  510.  349.  116.   59.  186.  252.  340.   29.  299.  193.
#    11.  347.  118.  261.  100.  258.   62. 1075.  151.  135.  268.  183.
#   408.  208.  103.   26.  249.  382.  357.  415.  216.  447.  159.  510.
#   292.  452.  285.  740.  248.  129.   65.  279.  549.   37.  153.    7.
#   462.  160.  133.   80.  237.  396.  316.  542.  483.   90.   81.  716.
#   263.  458.   98.  392.]
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas

# %%
print (hits_per_interaction)
# open a canvas to draw the histogram on
c2 = ROOT.TCanvas("Canvas2", "Title", 800, 600)
x_axis = np.arange(0,100)
g = ROOT.TGraph(len(hits_per_interaction), x_axis.astype(np.double),hits_per_interaction.astype(np.double))
g.SetTitle( "HGTD Hits per Interaction")
g.GetXaxis().SetTitle('Interaction')
g.GetYaxis().SetTitle('Number of hits')
g.GetXaxis().SetRange(-5,93)
g.SetFillColor(38)
g.Draw('AB')

c2.Draw()
c2.SaveAs("Hits per interaction.pdf")
# Out:
# [ 214.  167.  474.  244.  181.  184.  332.  114.  275.  149.   88.   49.
#   515.  204.  205.  452.  410.  150.  730.  437.  251.  247.  406.  307.
#   236.  220.  360.  434. 1017.  181.  426.  379.  129.  237.  813.  204.
#   321.  438.  510.  349.  116.   59.  186.  252.  340.   29.  299.  193.
#    11.  347.  118.  261.  100.  258.   62. 1075.  151.  135.  268.  183.
#   408.  208.  103.   26.  249.  382.  357.  415.  216.  447.  159.  510.
#   292.  452.  285.  740.  248.  129.   65.  279.  549.   37.  153.    7.
#   462.  160.  133.   80.  237.  396.  316.  542.  483.   90.   81.  716.
#   263.  458.   98.  392.]
# Info in <TCanvas::Print>: pdf file Hits per interaction.pdf has been created

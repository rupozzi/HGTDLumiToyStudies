# %% [markdown]
# # Toy MC for the ATLAS High Granularity Timing Detector

# %%
import ROOT
from ROOT import TCanvas, TGraph, gROOT
import numpy as np
import time
import math
import matplotlib.pyplot as plt
import time 
import scipy.interpolate as interp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import statistics

# %% [markdown]
# ### Constants

# %%
nr_of_channels = int(3.6 * 1e6)
channels_per_module = int(15*30)
total_modules = int(nr_of_channels/channels_per_module)
global_counter = 0

# %% [markdown]
# ### Noise Generator Class:
# This class takes in the parameters threshold and channel count (proportional to the number of interactions mu per bunch crossing) and calculates the mean number of channels activated by noise by calculating the probability mass that a part of the Gaussian distribution will be above the set average, and multiplies it with the total number of channels. The class has a function generate, which calculates a variation of the mean number of noise activated channels by drawing from a Poisson dist. with mean as parameter, and calculates how many of them are triggered during the small time window of 3.125ns (true value of them!) by drawing from a uniform dist. (0,1) for each number of noise activated channel and seeing how many are under 0.125 (3.125/25 = 0.125). Finally, it estimates the number of triggered channels in the small window by determining the number of channels triggered in one ns and multiplying by 3.125ns. This way, we have a true number of noise activated channels in the small window, and one that is estimated.
#
# try different big time windows , eg 4*3.125, lines 25-26. Change value of *big_window*

# %%
class noise_generator:
    def __init__(self, threshold, channel_count): 
        global global_counter
        low = 0
        high = 1000
        noise = ROOT.TF1("noise_gauss", "TMath::Gaus(x, 0, 5)", low, high)
        
        """Why divide with 2?? Why do we need a avg. value?"""
        #integrate normal dist. to get exact prob. above threshold and multiply with channel nr to get avg.
        self._mean = channel_count * noise.Integral(threshold, high)/noise.Integral(low, high) 
        #self._prng = ROOT.TRandom3(time.time_ns())
        global_counter += 1
        self._prng = ROOT.TRandom3(int(time.time()) + global_counter)

    def generate(self):
        """The first return value is the exact number of noise activated channels in the small window and
            the second return value is the estimated number of noise activated channels in the small window. (estimated from large window)
            (both results are in small window, both results are noise above threshold)
            noise_exact, noise_est = noise.generate()"""
        # Large time window 25ns
        # Small time window 3.125ns
        prng = self._prng
        total = prng.Poisson(self._mean) # number of noise above threshold in large window in this run.
        
        narrow_exact = 0
        big_window = 4*3.125
        
        #narrow_exact = (np.random.rand(total) < 0.125).sum()  # 3.125/25 = 0.125
        #noise_per_time = (total - narrow_exact)/(25 - 3.125)
        
        narrow_exact = (np.random.rand(total) < 3.125/big_window).sum() # ex. 3.125/(3.125*4) big window of 4 times 3.125 
        noise_per_time = (total - narrow_exact)/(big_window - 3.125)
        
        estimate = 3.125 * noise_per_time
        return narrow_exact, estimate

# %% [markdown]
#  ### Signal Generator Class:
#  This class takes the input parametes threshold and the real and guessed most probable peak voltage of the signal distribution (100mV when the sensors are new). It calculates the fraction of the Landau distribution that will be above the set threshold. It has a function generate, which takes in the paramter expected_count, that is, the estimated number of particles that will reach the detector (for mu=200 it is around 15k), then it determines a possible number of hits on the detector by drawing from a Poisson distribution around that parameter. Finally, for each calculated hit, it determines how many channels were triggered by signal from a particle by sampling a Landau distribution and checking how many of them are above the threshold. It returns the number of particles hitting the detector, and the number of signal-activated channels.

# %%
class signal_generator:
    def __init__(self, threshold, real_expected_voltage, guess_expected_voltage): # expected_voltage = expected peak voltage  (mu)
        global global_counter
        low = -100
        high = 1000
        self._threshold = threshold
        self._expected_voltage = real_expected_voltage
        signal_func = ROOT.TF1("sth", "TMath::Landau(x, %f, %f)" % (guess_expected_voltage, guess_expected_voltage/4), low, high)
        self.fraction_above = signal_func.Integral(threshold, high)/signal_func.Integral(low, high) #fraction of the function that is above threshold
        #self._prng = ROOT.TRandom3(time.time_ns())
        global_counter += 1
        self._prng = ROOT.TRandom3(int(time.time()) + global_counter)
    
    def generate(self, expected_count):
        """The paramater is the expected number of particles that reach the detector.
            The first return value is the number of particles that reached the detector and
            the second return value is the number of activated channels.
            signal_real_total, signal_above = signal.generate(30)"""
        prng = self._prng
        expected_voltage = self._expected_voltage
        threshold = self._threshold
        
        signal_count = prng.Poisson(expected_count)
        above_threshold_count = 0
        sigma = expected_voltage/4
        for i in range(signal_count):
            if prng.Landau(expected_voltage, sigma) > threshold: # 1/4 is just the refernce 25/100
                above_threshold_count += 1
        return signal_count, above_threshold_count

# %% [markdown]
# ## Simulation function

# %%
def simulation (nr_of_channels, ratio_of_channels_to_sample, expected_count, bunch_crossings, threshold, peak_mpv_voltage, guess_mpv_voltage):
    """For a number of BC, we get two lists: total_actual_signal_count and total_estimated_signal_count for each BC"""

    channel_count = nr_of_channels*ratio_of_channels_to_sample
    #avg_particles_reaching_detector = channel_count * signal_to_channel_count_ratio

    #generate the noise
    noise_gen = noise_generator(threshold, channel_count)
    #generate the signal
    signal_gen = signal_generator(threshold, peak_mpv_voltage, guess_mpv_voltage)

    result_true_signal_count = np.zeros(bunch_crossings)
    result_estimated_signal_count = np.zeros(bunch_crossings)
    error_estimation = 0
    signal_fraction_above = signal_gen.fraction_above
    deviation_from_true = np.zeros(bunch_crossings)
    for BC in range(bunch_crossings):
        # both results are in small window, both are noise above threshold
        noise_exact, noise_est = noise_gen.generate()

        # The paramater is the expected number of particles that reach the detector.
        # The first return value is the number of particles that reached the detector and 
        # the second return value is the number of activated channels.
        total_actual_signal, signal_above = signal_gen.generate(expected_count)

        # from the total activations, estimate how much was produced by actual signal
        total_activations = signal_above + noise_exact  # total activations in small window (i.e. above threshold)
        #print("\nBunch Crossing %d:" %(BC+1))
        #print("Signal- and noise-activated channels: %d" %(total_activations))
        #print ("Noise-activated channels: %d" %(noise_exact))
        #total real activations minus estimation of signal, then divide with the prob. mass for Landau to be above threshold
        total_signal_est = (total_activations - noise_est)/signal_fraction_above 

        # assign the results
        result_true_signal_count[BC] = total_actual_signal #exact count in the small window
        result_estimated_signal_count[BC] = total_signal_est #estimated count 
        
        deviation_from_true [BC] = total_signal_est - total_actual_signal
    return result_true_signal_count, result_estimated_signal_count, deviation_from_true/bunch_crossings

# %%
threshold = 20
true_signal, estimated_signal, dev = simulation (nr_of_channels, ratio_of_channels_to_sample, expected_count, bunch_crossings, threshold, peak_mpv_voltage, guess_mpv_voltage)
print (dev)
print(true_signal)
print(estimated_signal)
# Out:
# [-0.14762602 -0.01098445  0.09906643  0.0089875  -0.07764004 -0.04764697
#  -0.02432288 -0.22430839 -0.17096854  0.18569839  0.06568846 -0.10094916
#  -0.05098571 -0.02094538 -0.03098902 -0.07761609 -0.03763153  0.02901917
#   0.10568956  0.07572139 -0.06428822 -0.06098351 -0.05764823  0.00572013
#  -0.01763358  0.12570264 -0.05767974  0.0356486  -0.06431721 -0.04766556
#   0.02568326  0.18568736 -0.12763153  0.02233696 -0.05100982 -0.11763815
#   0.07234909 -0.17432414  0.00236106  0.07904249 -0.15428523  0.07571839
#  -0.13098508 -0.20432005 -0.0209928  -0.04432824 -0.03764634 -0.06098382
#  -0.05098382  0.07900625 -0.02098367 -0.03427137 -0.14096366  0.02906108
#   0.01571257  0.02569461  0.13569854  0.1323984  -0.01431642  0.13902752
#  -0.03763421 -0.09763421  0.02236689  0.00906155 -0.10433927 -0.00430303
#  -0.02431579 -0.13430949 -0.04763831 -0.06767186 -0.15764634  0.04238769
#  -0.00430476 -0.00765548 -0.07094003 -0.11097343  0.03235775  0.02901917
#  -0.06760885 -0.01427373  0.01568358 -0.12761909 -0.09095279  0.05236484
#   0.14571729 -0.13765044 -0.01762145  0.01568185  0.00571981 -0.08763768
#   0.10571052  0.00906155 -0.03428586 -0.09428917 -0.14432666 -0.01762917
#   0.01236721 -0.04765721 -0.04432966  0.00237351]
# [15084. 14911. 15223. 14731. 14988. 14941. 14880. 14992. 15028. 14994.
#  14943. 15144. 14907. 15160. 14884. 15140. 15038. 14930. 14946. 15151.
#  15104. 14922. 14934. 15150. 15023. 15027. 14734. 14693. 14920. 14823.
#  14914. 14924. 15047. 14832. 14754. 15004. 14904. 14887. 14987. 15073.
#  15132. 15132. 14919. 14916. 14859. 14848. 14944. 14920. 14919. 14843.
#  14917. 15208. 15056. 15196. 15101. 14986. 15000. 15211. 14920. 14972.
#  15021. 15027. 15022. 15201. 14784. 15004. 14925. 14976. 14996. 14785.
#  14956. 15152. 14993. 14883. 15199. 14991. 14963. 14930. 15185. 15191.
#  14917. 15126. 15120. 15006. 15118. 14928. 15100. 14906. 15148. 15004.
#  15079. 15201. 15116. 15101. 14868. 15051. 15025. 14876. 14839. 15066.]
# [15069.23739808 14909.9015546  15232.90664316 14731.89875037
#  14980.23599597 14936.23530279 14877.56771188 14969.56916126
#  15010.90314576 15012.56983868 14949.56884618 15133.90508351
#  14901.90142856 15157.90546161 14880.90109773 15132.23839059
#  15034.23684669 14932.90191694 14956.56895645 15158.57213878
#  15097.57117778 14915.90164912 14928.23517676 15150.57201274
#  15021.23664188 15039.57026404 14728.23202594 14696.5648604
#  14913.56827903 14818.23344381 14916.56832629 14942.5687359
#  15034.23684669 14834.23369587 14748.89901819 14992.23618502
#  14911.23490894 14869.56758585 14987.23610625 15080.90424854
#  15116.5714771  15139.57183945 14905.90149158 14895.56799546
#  14856.90071963 14843.56717624 14940.2353658  14913.90161761
#  14913.90161761 14850.90062511 14914.90163337 15204.57286346
#  15041.90363413 15198.90610752 15102.57125655 14988.56946058
#  15013.56985444 15224.23983996 14918.5683578  14985.90275191
#  15017.23657887 15017.23657887 15024.23668915 15201.90615479
#  14773.56607346 15003.5696969  14922.56842082 14962.56905098
#  14991.23616926 14778.23281364 14940.2353658  15156.23876868
#  14992.5695236  14882.23445207 15191.90599724 14979.90265738
#  14966.23577541 14932.90191694 15178.23911527 15189.57262715
#  14918.5683578  15113.23809126 15110.90472117 15011.23648434
#  15132.57172917 14914.2349562  15098.23785495 14907.5681845
#  15148.57198124 14995.23623228 15089.57105175 15201.90615479
#  15112.57141409 15091.57108325 14853.56733378 15049.237083
#  15026.23672065 14871.23427877 14834.56703446 15066.23735082]

# %%
"""Parameters for the simulation"""
peak_mpv_voltage = 100 #mV, mpv: most probable value
guess_mpv_voltage = 100 #mV
mu = 200
"""exp number of particles on detector proportional to mu, try also non-linear relationship as in christian's plot """
expected_count = (15*1e3/200)*mu #expected number of particles reaching the HGTD for mu=200, no more than 20k
bunch_crossings = 100
ratio_of_channels_to_sample = 1
print("Expected count: %f" %expected_count)
# Out:
# Expected count: 15000.000000

# %% [markdown]
#  ### Graphical estimation of best threshold with regards to deviation from the true signal

# %%
min_threshold = 20 #mV
max_threshold = 35 #mV
threshold_array = np.linspace(min_threshold,max_threshold,36)
total_deviation= np.zeros(len(threshold_array))
iteration = 0
start_time = time.time()

for threshold in threshold_array:
    
    true_signal, estimated_signal, dev = simulation (nr_of_channels, ratio_of_channels_to_sample, expected_count, bunch_crossings, threshold, peak_mpv_voltage, guess_mpv_voltage)
    
    """Get the total deviation from the total simulated signals vs the expected signals.
        Returns both the total deviation as a positive number"""
    true_signal_sum = true_signal.sum()
    if true_signal_sum == 0:
        deviation = 0
    deviation = abs( estimated_signal.sum() / true_signal_sum -1)
    total_deviation[iteration] = deviation
    print("Deviation for threshold %f: %f" %(threshold, total_deviation[iteration]))
    iteration = iteration+1

best = find_best_threshold(total_deviation)
print("Best threshold: %d"%best)

c1 = TCanvas( 'c1', 'Graph', 200, 10, 700, 500 )
#c1.SetLogy()

g = TGraph(len(threshold_array), threshold_array.astype(np.double),total_deviation.astype(np.double))
g.SetTitle( "#splitline{Deviation as a function of threshold, mu=%f, BC=%d, mpv_voltage=%d mV}{\n large window 3 times the smaller}"  %(mu, bunch_crossings, peak_mpv_voltage))
g.GetXaxis().SetTitle( 'Threshold [mV]' )
g.GetYaxis().SetTitle( 'Deviation' )
g.GetYaxis().SetRange(0,10);
g.SetLineColor(2)
g.Draw(); 
c1.Draw()
c1.Modified()
c1.Update();
print("CPU time: %s seconds" % (time.time() - start_time))
# Out:
# Deviation for threshold 20.000000: 0.000082
# Deviation for threshold 20.428571: 0.000072
# Deviation for threshold 20.857143: 0.000025
# Deviation for threshold 21.285714: 0.000177
# Deviation for threshold 21.714286: 0.000235
# Deviation for threshold 22.142857: 0.000063
# Deviation for threshold 22.571429: 0.000056
# Deviation for threshold 23.000000: 0.000080
# Deviation for threshold 23.428571: 0.000002
# Deviation for threshold 23.857143: 0.000066
# Deviation for threshold 24.285714: 0.000001
# Deviation for threshold 24.714286: 0.000019
# Deviation for threshold 25.142857: 0.000029
# Deviation for threshold 25.571429: 0.000018
# Deviation for threshold 26.000000: 0.000000
# Deviation for threshold 26.428571: 0.000006
# Deviation for threshold 26.857143: 0.000066
# Deviation for threshold 27.285714: 0.000014
# Deviation for threshold 27.714286: 0.000055
# Deviation for threshold 28.142857: 0.000024
# Deviation for threshold 28.571429: 0.000052
# Deviation for threshold 29.000000: 0.000058
# Deviation for threshold 29.428571: 0.000037
# Deviation for threshold 29.857143: 0.000016
# Deviation for threshold 30.285714: 0.000031
# Deviation for threshold 30.714286: 0.000083
# Deviation for threshold 31.142857: 0.000053
# Deviation for threshold 31.571429: 0.000029
# Deviation for threshold 32.000000: 0.000012
# Deviation for threshold 32.428571: 0.000067
# Deviation for threshold 32.857143: 0.000044
# Deviation for threshold 33.285714: 0.000041
# Deviation for threshold 33.714286: 0.000146
# Deviation for threshold 34.142857: 0.000042
# Deviation for threshold 34.571429: 0.000050
# Deviation for threshold 35.000000: 0.000033
# Size of array: 1
# best threshold: 26.000000
# Best threshold: 26
# CPU time: 1.5782678127288818 seconds
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %% [markdown]
# ### Finer search for the best threshold: exact value
# Use nr_of_simulations?? Maybe redundant?

# %%
min_threshold = 5#mV
max_threshold = 90#mV
threshold_array = np.linspace(min_threshold,max_threshold,86)
total_deviation= np.zeros(len(threshold_array))
iteration = 0
start_time = time.time()
dev = np.zeros(len(threshold_array))
mean_values = []
std_values = []
val = []
for threshold in threshold_array:
    
    true_signal, estimated_signal, dev_per_BC = simulation (nr_of_channels, ratio_of_channels_to_sample, expected_count, bunch_crossings, threshold, peak_mpv_voltage, guess_mpv_voltage)
    
    """Get the total deviation from the total simulated signals vs the expected signals.
        Returns both the total deviation as a positive number"""

    true_signal_sum = true_signal.sum()
    if true_signal_sum == 0:
        deviation = 0
    deviation = abs( estimated_signal.sum() / true_signal_sum -1)
    total_deviation[iteration] = deviation
    print("\nDeviation for threshold %f: %f" %(threshold, total_deviation[iteration]))
    
    
    mean_values.append(abs(np.mean(dev_per_BC)))
    print ("Mean dev for threshold %f: %f" %(threshold, mean_values[iteration]))
    std_values.append(np.std(dev_per_BC))
    print ("Std for threshold %f: %f" %(threshold, std_values[iteration]))
    val.append (abs(np.mean(dev_per_BC))+np.std(dev_per_BC))
    iteration = iteration+1
print("dev")
print(total_deviation)
print("mean")
print (mean_values)
print ("std")
print (std_values)

plt.plot(threshold_array, total_deviation)
#plt.yscale("log")
plt.xlabel("Threshold [mV]")
plt.ylabel("Deviation")
plt.title ('Deviation as a function of threshold, mu=%f \n BC=%d, mpv_voltage=%d mV, ' %(mu, bunch_crossings, peak_mpv_voltage))
plt.show()
#calculate best threshold

find_best_threshold(total_deviation)

plt.errorbar(threshold_array, mean_values, yerr= std_values, linestyle='None')
plt.yscale("log")
plt.xlabel("Threshold [mV]")
plt.ylabel("Deviation")
plt.title ('Mean as a function of threshold, mu=%f \n BC=%d, mpv_voltage=%d mV, ' %(mu, bunch_crossings, peak_mpv_voltage))
plt.show()
# Out:
# Deviation for threshold 5.000000: 0.005074
# Mean dev for threshold 5.000000: 0.761034
# Std for threshold 5.000000: 5.975992
#
# Deviation for threshold 6.000000: 0.000808
# Mean dev for threshold 6.000000: 0.121102
# Std for threshold 6.000000: 4.894812
#
# Deviation for threshold 7.000000: 0.003062
# Mean dev for threshold 7.000000: 0.459163
# Std for threshold 7.000000: 4.298498
#
# Deviation for threshold 8.000000: 0.000204
# Mean dev for threshold 8.000000: 0.030641
# Std for threshold 8.000000: 4.082536
#
# Deviation for threshold 9.000000: 0.001522
# Mean dev for threshold 9.000000: 0.228380
# Std for threshold 9.000000: 2.688064
#
# Deviation for threshold 10.000000: 0.000486
# Mean dev for threshold 10.000000: 0.073077
# Std for threshold 10.000000: 2.329276
#
# Deviation for threshold 11.000000: 0.001033
# Mean dev for threshold 11.000000: 0.154973
# Std for threshold 11.000000: 1.858180
#
# Deviation for threshold 12.000000: 0.000521
# Mean dev for threshold 12.000000: 0.078034
# Std for threshold 12.000000: 1.538113
#
# Deviation for threshold 13.000000: 0.000298
# Mean dev for threshold 13.000000: 0.044721
# Std for threshold 13.000000: 0.989351
#
# Deviation for threshold 14.000000: 0.000252
# Mean dev for threshold 14.000000: 0.037816
# Std for threshold 14.000000: 0.718558
#
# Deviation for threshold 15.000000: 0.000259
# Mean dev for threshold 15.000000: 0.038892
# Std for threshold 15.000000: 0.619366
#
# Deviation for threshold 16.000000: 0.000047
# Mean dev for threshold 16.000000: 0.007025
# Std for threshold 16.000000: 0.355297
#
# Deviation for threshold 17.000000: 0.000264
# Mean dev for threshold 17.000000: 0.039626
# Std for threshold 17.000000: 0.264394
#
# Deviation for threshold 18.000000: 0.000149
# Mean dev for threshold 18.000000: 0.022326
# Std for threshold 18.000000: 0.224082
#
# Deviation for threshold 19.000000: 0.000065
# Mean dev for threshold 19.000000: 0.009726
# Std for threshold 19.000000: 0.134030
#
# Deviation for threshold 20.000000: 0.000013
# Mean dev for threshold 20.000000: 0.001896
# Std for threshold 20.000000: 0.084230
#
# Deviation for threshold 21.000000: 0.000012
# Mean dev for threshold 21.000000: 0.001826
# Std for threshold 21.000000: 0.050678
#
# Deviation for threshold 22.000000: 0.000014
# Mean dev for threshold 22.000000: 0.002040
# Std for threshold 22.000000: 0.038575
#
# Deviation for threshold 23.000000: 0.000009
# Mean dev for threshold 23.000000: 0.001283
# Std for threshold 23.000000: 0.027649
#
# Deviation for threshold 24.000000: 0.000009
# Mean dev for threshold 24.000000: 0.001397
# Std for threshold 24.000000: 0.015768
#
# Deviation for threshold 25.000000: 0.000001
# Mean dev for threshold 25.000000: 0.000193
# Std for threshold 25.000000: 0.016690
#
# Deviation for threshold 26.000000: 0.000007
# Mean dev for threshold 26.000000: 0.001084
# Std for threshold 26.000000: 0.015546
#
# Deviation for threshold 27.000000: 0.000013
# Mean dev for threshold 27.000000: 0.001906
# Std for threshold 27.000000: 0.017347
#
# Deviation for threshold 28.000000: 0.000000
# Mean dev for threshold 28.000000: 0.000030
# Std for threshold 28.000000: 0.019896
#
# Deviation for threshold 29.000000: 0.000012
# Mean dev for threshold 29.000000: 0.001745
# Std for threshold 29.000000: 0.021938
#
# Deviation for threshold 30.000000: 0.000010
# Mean dev for threshold 30.000000: 0.001561
# Std for threshold 30.000000: 0.022134
#
# Deviation for threshold 31.000000: 0.000026
# Mean dev for threshold 31.000000: 0.003890
# Std for threshold 31.000000: 0.025621
#
# Deviation for threshold 32.000000: 0.000005
# Mean dev for threshold 32.000000: 0.000707
# Std for threshold 32.000000: 0.031815
#
# Deviation for threshold 33.000000: 0.000036
# Mean dev for threshold 33.000000: 0.005322
# Std for threshold 33.000000: 0.034084
#
# Deviation for threshold 34.000000: 0.000019
# Mean dev for threshold 34.000000: 0.002859
# Std for threshold 34.000000: 0.036304
#
# Deviation for threshold 35.000000: 0.000032
# Mean dev for threshold 35.000000: 0.004776
# Std for threshold 35.000000: 0.040183
#
# Deviation for threshold 36.000000: 0.000079
# Mean dev for threshold 36.000000: 0.011901
# Std for threshold 36.000000: 0.043018
#
# Deviation for threshold 37.000000: 0.000043
# Mean dev for threshold 37.000000: 0.006461
# Std for threshold 37.000000: 0.056791
#
# Deviation for threshold 38.000000: 0.000111
# Mean dev for threshold 38.000000: 0.016629
# Std for threshold 38.000000: 0.049764
#
# Deviation for threshold 39.000000: 0.000134
# Mean dev for threshold 39.000000: 0.020080
# Std for threshold 39.000000: 0.067405
#
# Deviation for threshold 40.000000: 0.000114
# Mean dev for threshold 40.000000: 0.017093
# Std for threshold 40.000000: 0.069189
#
# Deviation for threshold 41.000000: 0.000123
# Mean dev for threshold 41.000000: 0.018448
# Std for threshold 41.000000: 0.087405
#
# Deviation for threshold 42.000000: 0.000186
# Mean dev for threshold 42.000000: 0.027881
# Std for threshold 42.000000: 0.068911
#
# Deviation for threshold 43.000000: 0.000120
# Mean dev for threshold 43.000000: 0.017989
# Std for threshold 43.000000: 0.093988
#
# Deviation for threshold 44.000000: 0.000161
# Mean dev for threshold 44.000000: 0.024134
# Std for threshold 44.000000: 0.089554
#
# Deviation for threshold 45.000000: 0.000135
# Mean dev for threshold 45.000000: 0.020239
# Std for threshold 45.000000: 0.098971
#
# Deviation for threshold 46.000000: 0.000234
# Mean dev for threshold 46.000000: 0.035118
# Std for threshold 46.000000: 0.111705
#
# Deviation for threshold 47.000000: 0.000287
# Mean dev for threshold 47.000000: 0.043078
# Std for threshold 47.000000: 0.110524
#
# Deviation for threshold 48.000000: 0.000346
# Mean dev for threshold 48.000000: 0.051920
# Std for threshold 48.000000: 0.129341
#
# Deviation for threshold 49.000000: 0.000409
# Mean dev for threshold 49.000000: 0.061298
# Std for threshold 49.000000: 0.133105
#
# Deviation for threshold 50.000000: 0.000534
# Mean dev for threshold 50.000000: 0.080214
# Std for threshold 50.000000: 0.148732
#
# Deviation for threshold 51.000000: 0.000581
# Mean dev for threshold 51.000000: 0.087068
# Std for threshold 51.000000: 0.146097
#
# Deviation for threshold 52.000000: 0.000631
# Mean dev for threshold 52.000000: 0.094666
# Std for threshold 52.000000: 0.169722
#
# Deviation for threshold 53.000000: 0.000538
# Mean dev for threshold 53.000000: 0.080664
# Std for threshold 53.000000: 0.160290
#
# Deviation for threshold 54.000000: 0.000611
# Mean dev for threshold 54.000000: 0.091689
# Std for threshold 54.000000: 0.188618
#
# Deviation for threshold 55.000000: 0.000705
# Mean dev for threshold 55.000000: 0.105764
# Std for threshold 55.000000: 0.209001
#
# Deviation for threshold 56.000000: 0.000946
# Mean dev for threshold 56.000000: 0.141764
# Std for threshold 56.000000: 0.226113
#
# Deviation for threshold 57.000000: 0.001049
# Mean dev for threshold 57.000000: 0.157292
# Std for threshold 57.000000: 0.229447
#
# Deviation for threshold 58.000000: 0.001003
# Mean dev for threshold 58.000000: 0.150445
# Std for threshold 58.000000: 0.230957
#
# Deviation for threshold 59.000000: 0.001276
# Mean dev for threshold 59.000000: 0.191276
# Std for threshold 59.000000: 0.211238
#
# Deviation for threshold 60.000000: 0.001377
# Mean dev for threshold 60.000000: 0.206603
# Std for threshold 60.000000: 0.247960
#
# Deviation for threshold 61.000000: 0.001293
# Mean dev for threshold 61.000000: 0.193897
# Std for threshold 61.000000: 0.280923
#
# Deviation for threshold 62.000000: 0.001531
# Mean dev for threshold 62.000000: 0.229484
# Std for threshold 62.000000: 0.279451
#
# Deviation for threshold 63.000000: 0.001497
# Mean dev for threshold 63.000000: 0.224510
# Std for threshold 63.000000: 0.268832
#
# Deviation for threshold 64.000000: 0.001707
# Mean dev for threshold 64.000000: 0.256244
# Std for threshold 64.000000: 0.285506
#
# Deviation for threshold 65.000000: 0.002107
# Mean dev for threshold 65.000000: 0.316264
# Std for threshold 65.000000: 0.305614
#
# Deviation for threshold 66.000000: 0.002324
# Mean dev for threshold 66.000000: 0.348510
# Std for threshold 66.000000: 0.364837
#
# Deviation for threshold 67.000000: 0.002011
# Mean dev for threshold 67.000000: 0.301299
# Std for threshold 67.000000: 0.290650
#
# Deviation for threshold 68.000000: 0.002679
# Mean dev for threshold 68.000000: 0.402167
# Std for threshold 68.000000: 0.362108
#
# Deviation for threshold 69.000000: 0.002508
# Mean dev for threshold 69.000000: 0.375865
# Std for threshold 69.000000: 0.361207
#
# Deviation for threshold 70.000000: 0.003066
# Mean dev for threshold 70.000000: 0.460375
# Std for threshold 70.000000: 0.367972
# Deviation for threshold 71.000000: 0.003296
# Mean dev for threshold 71.000000: 0.494525
# Std for threshold 71.000000: 0.407536
#
# Deviation for threshold 72.000000: 0.003764
# Mean dev for threshold 72.000000: 0.564901
# Std for threshold 72.000000: 0.419354
#
# Deviation for threshold 73.000000: 0.003239
# Mean dev for threshold 73.000000: 0.486436
# Std for threshold 73.000000: 0.339140
#
# Deviation for threshold 74.000000: 0.003689
# Mean dev for threshold 74.000000: 0.553632
# Std for threshold 74.000000: 0.423981
#
# Deviation for threshold 75.000000: 0.004023
# Mean dev for threshold 75.000000: 0.603683
# Std for threshold 75.000000: 0.419461
#
# Deviation for threshold 76.000000: 0.004166
# Mean dev for threshold 76.000000: 0.625106
# Std for threshold 76.000000: 0.465878
#
# Deviation for threshold 77.000000: 0.004747
# Mean dev for threshold 77.000000: 0.713115
# Std for threshold 77.000000: 0.474983
#
# Deviation for threshold 78.000000: 0.004554
# Mean dev for threshold 78.000000: 0.683277
# Std for threshold 78.000000: 0.426196
#
# Deviation for threshold 79.000000: 0.004741
# Mean dev for threshold 79.000000: 0.711933
# Std for threshold 79.000000: 0.533869
#
# Deviation for threshold 80.000000: 0.005435
# Mean dev for threshold 80.000000: 0.815164
# Std for threshold 80.000000: 0.526566
#
# Deviation for threshold 81.000000: 0.005488
# Mean dev for threshold 81.000000: 0.823614
# Std for threshold 81.000000: 0.527344
#
# Deviation for threshold 82.000000: 0.006373
# Mean dev for threshold 82.000000: 0.956026
# Std for threshold 82.000000: 0.557691
#
# Deviation for threshold 83.000000: 0.006472
# Mean dev for threshold 83.000000: 0.971219
# Std for threshold 83.000000: 0.546365
#
# Deviation for threshold 84.000000: 0.006288
# Mean dev for threshold 84.000000: 0.942744
# Std for threshold 84.000000: 0.571330
#
# Deviation for threshold 85.000000: 0.006778
# Mean dev for threshold 85.000000: 1.015990
# Std for threshold 85.000000: 0.631607
#
# Deviation for threshold 86.000000: 0.007702
# Mean dev for threshold 86.000000: 1.156625
# Std for threshold 86.000000: 0.622053
#
# Deviation for threshold 87.000000: 0.008606
# Mean dev for threshold 87.000000: 1.291307
# Std for threshold 87.000000: 0.524948
#
# Deviation for threshold 88.000000: 0.008529
# Mean dev for threshold 88.000000: 1.280138
# Std for threshold 88.000000: 0.638911
#
# Deviation for threshold 89.000000: 0.007986
# Mean dev for threshold 89.000000: 1.198167
# Std for threshold 89.000000: 0.577254
#
# Deviation for threshold 90.000000: 0.008512
# Mean dev for threshold 90.000000: 1.273194
# Std for threshold 90.000000: 0.671576
# dev
# [5.07434754e-03 8.08003824e-04 3.06198113e-03 2.04369449e-04
#  1.52157354e-03 4.86392364e-04 1.03346254e-03 5.20878720e-04
#  2.98268264e-04 2.52142197e-04 2.59257094e-04 4.68613444e-05
#  2.64157458e-04 1.48873300e-04 6.47685242e-05 1.26417852e-05
#  1.21842089e-05 1.35985334e-05 8.56439179e-06 9.30318645e-06
#  1.28733496e-06 7.22883048e-06 1.26797822e-05 2.02768079e-07
#  1.16151186e-05 1.03970815e-05 2.59764814e-05 4.71753004e-06
#  3.55211218e-05 1.90562118e-05 3.17949808e-05 7.94683109e-05
#  4.30705084e-05 1.10897455e-04 1.33742904e-04 1.13833016e-04
#  1.22942055e-04 1.85655068e-04 1.19985806e-04 1.60900090e-04
#  1.35089021e-04 2.34130003e-04 2.87116759e-04 3.46306421e-04
#  4.09487578e-04 5.33945488e-04 5.81310390e-04 6.31390600e-04
#  5.38123970e-04 6.10900098e-04 7.05389447e-04 9.45557624e-04
#  1.04870937e-03 1.00283433e-03 1.27598374e-03 1.37660817e-03
#  1.29261036e-03 1.53127498e-03 1.49668756e-03 1.70721823e-03
#  2.10730779e-03 2.32351310e-03 2.01123471e-03 2.67900786e-03
#  2.50797209e-03 3.06625194e-03 3.29623070e-03 3.76398839e-03
#  3.23907710e-03 3.68928666e-03 4.02274004e-03 4.16575441e-03
#  4.74728235e-03 4.55396500e-03 4.74063697e-03 5.43540875e-03
#  5.48846948e-03 6.37272755e-03 6.47222466e-03 6.28753484e-03
#  6.77760645e-03 7.70159230e-03 8.60630497e-03 8.52933966e-03
#  7.98590538e-03 8.51171127e-03]
# mean
# [0.7610344064948401, 0.12110207791462639, 0.45916274913012645, 0.030640600623074773, 0.22837981975072247, 0.07307680473553976, 0.154973392347044, 0.07803435161558682, 0.04472106096963106, 0.0378161858731517, 0.038892193686367316, 0.0070248716689478895, 0.03962599616803562, 0.02232632031568828, 0.009726399378113638, 0.0018955825922594167, 0.001826355646103186, 0.002040004389524438, 0.0012829004990037001, 0.0013967766926854894, 0.00019313229935851266, 0.0010844033660081546, 0.001906211255141534, 3.040229563539487e-05, 0.0017447894315626403, 0.0015610552498807008, 0.003890469041982943, 0.0007073549453491075, 0.00532178867898565, 0.002858795745512726, 0.004776372382155206, 0.011901142457195786, 0.006460912212287439, 0.0166288071729141, 0.02007985200252715, 0.017093370572559614, 0.01844778732389332, 0.027880954071976157, 0.017989183979184597, 0.02413385498122261, 0.020238523726144923, 0.03511837658839468, 0.04307750551530407, 0.05191964392101544, 0.061297915360314245, 0.08021425691699186, 0.08706785633141935, 0.09466634989479063, 0.08066354534937219, 0.09168883494670789, 0.10576369540622926, 0.14176376691458117, 0.15729224778035697, 0.15044510558842306, 0.1912764698178865, 0.2066030064797855, 0.19389659536656162, 0.22948437203528904, 0.22450956907151182, 0.25624355489446043, 0.316263910869338, 0.34851046880097597, 0.30129925129792506, 0.4021673019587139, 0.375864510603516, 0.4603747314050406, 0.4945252506214682, 0.5649005074011568, 0.48643585317715626, 0.5536320654746198, 0.6036833453066425, 0.6251064416155684, 0.71311491724889, 0.6832769086682744, 0.7119327415504219, 0.8151640129211253, 0.8236139995221705, 0.9560257526961813, 0.971219443935069, 0.9427441720798545, 1.0159903171867253, 1.1566251318785152, 1.2913072099057588, 1.2801378841997977, 1.1981669111967619, 1.2731936877200634]
# std
# [5.975992245755299, 4.894812086372276, 4.298498442194228, 4.0825361575288825, 2.6880637967194017, 2.3292755262669687, 1.8581798291919298, 1.5381131649353554, 0.9893510866560076, 0.7185580569583436, 0.6193662675542962, 0.3552971988796348, 0.26439363546314476, 0.22408232913359447, 0.13403032997536662, 0.08423024244760795, 0.05067785845866139, 0.03857540177836242, 0.027649025618685312, 0.015768067903951532, 0.016689861979248856, 0.015545986808379604, 0.017346730561102648, 0.019896396704777858, 0.021937690965118464, 0.0221342093517646, 0.02562051433462362, 0.031815157603033266, 0.03408427296306659, 0.03630369610030757, 0.04018328458424162, 0.0430176329534188, 0.05679149211684276, 0.04976377362430544, 0.06740494469012276, 0.06918910859861845, 0.08740469380123694, 0.06891124094769328, 0.09398764642629293, 0.08955380208109552, 0.09897137842424046, 0.11170474796153639, 0.11052385109208072, 0.12934106949807683, 0.13310485892153512, 0.14873156427385714, 0.14609742148810057, 0.16972154752945653, 0.16028953615917935, 0.18861816500982942, 0.2090005431686216, 0.226112684946452, 0.2294470908607439, 0.2309568809808219, 0.21123800110644508, 0.2479602032345082, 0.28092276816898365, 0.2794513267840903, 0.2688318772979249, 0.285506134142464, 0.30561384593430385, 0.36483698955727084, 0.2906496926849822, 0.36210814872417935, 0.3612069947426306, 0.3679717374883784, 0.40753561636284036, 0.4193539930631603, 0.33914031618608714, 0.4239813673871693, 0.4194609088475475, 0.4658784444669513, 0.4749832017310992, 0.4261961637327385, 0.5338687732421303, 0.5265656256837147, 0.5273442566924201, 0.5576909096217907, 0.5463648344865484, 0.5713303858503284, 0.6316068573603104, 0.6220527711726187, 0.5249478703056266, 0.6389105983339968, 0.5772538972883586, 0.671575655452795]
# Size of array: 1
# best threshold: 28.000000

# %% [markdown]
# ### Function to find best threshold

# %%
def find_best_threshold (total_deviation):
    """Input parameter is a list of the deviation for each threshold, returns the best threshold with lowest deviation"""
    total_deviation = total_deviation.tolist()
    total_deviation = [round(num, 6) for num in total_deviation]

    best_array_indexes = [i for i, x in enumerate(total_deviation) if x == min(total_deviation)]
    print("Size of array: %d" %len(best_array_indexes))
    best_thresholds_array = np.zeros(len(best_array_indexes))
    if len(best_array_indexes)==1:
         print("best threshold: %f" %(threshold_array[best_array_indexes[0]]))
         return threshold_array[best_array_indexes[0]]
    
    else: 
        for i in range (len(best_array_indexes)):
            best_thresholds_array[i] = threshold_array[best_array_indexes[i]]
        print (best_thresholds_array)
        return sum(best_thresholds_array)/len(best_thresholds_array)

# %% [markdown]
# ### Study how the threshold and the deviation changes with worsening of the sensor with time because of radiation damage

# %%
start_time = time.time()
min_mpv_peak = 25 #mV, the sensor at its worst state
max_mpv_peak = 100 #mV, new sensors
mpv_peak_array = np.linspace(min_mpv_peak,max_mpv_peak,8) #use even number of steps to get the 3D graph to work
total_deviation= np.zeros(len(threshold_array))
iteration_peak = 0
start_time = time.time()
best_threshold_array = np.zeros (len(mpv_peak_array))
min_deviation_array = np.zeros(len(mpv_peak_array))
for peak_value_step in mpv_peak_array:
    print("\nSimulations for mpv peak voltage %dmV\n" %peak_value_step)
    min_threshold = 10#mV
    max_threshold = 35#mV
    threshold_array = np.linspace(min_threshold,max_threshold,26)
    total_deviation= np.zeros(len(threshold_array))
    iteration = 0
    for threshold in threshold_array:
        true_signal, estimated_signal, dev = simulation (nr_of_channels, ratio_of_channels_to_sample, expected_count, bunch_crossings, threshold, peak_value_step, peak_value_step)
        """Get the total deviation from the total simulated signals vs the expected signals.
            Returns both the total deviation as a positive number"""

        true_signal_sum = true_signal.sum()
        if true_signal_sum == 0:
            deviation = 0
        deviation = abs( estimated_signal.sum() / true_signal_sum -1)
        total_deviation[iteration] = deviation
        print("Deviation for threshold %fmV: %fmV" %(threshold, total_deviation[iteration]))
        iteration = iteration+1
    
    best_threshold_array [iteration_peak] = find_best_threshold(total_deviation)
    min_deviation_array [iteration_peak] = min(total_deviation)
    print ("Best threshold for mpv peak voltage %dmV: %fmV" %(peak_value_step,best_threshold_array[iteration_peak]))
    print ("Minimum deviation for mpv peak voltage %d: %f" %(peak_value_step, min_deviation_array[iteration_peak]))
    #print("Deviation for mpv  %f: %f" %(peak_value_step, best_threshold_array[iteration_peak]))     
    iteration_peak = iteration_peak+1

plt.scatter(mpv_peak_array, best_threshold_array, marker = "x", color='red')
plt.title("Best threshold as a function of sensor quality, mu=%f \n BC=%d" %(mu, bunch_crossings))
plt.xlabel("mpv Voltage [mV]")
plt.ylabel("Best threshold [mV]")
plt.show()

plt.scatter(mpv_peak_array, min_deviation_array, marker = "x", color='red')
plt.title("Deviation as a function of sensor quality, mu=%f \n BC=%d" %(mu, bunch_crossings))
plt.xlabel("mpv Voltage [mV]")
plt.ylabel("Smallest deviation")
plt.show()


print("CPU time: %s seconds" % (time.time() - start_time))
# Out:
# Simulations for mpv peak voltage 25mV
#
# Deviation for threshold 10.000000mV: 0.000692mV
# Deviation for threshold 11.000000mV: 0.000339mV
# Deviation for threshold 12.000000mV: 0.000745mV
# Deviation for threshold 13.000000mV: 0.000420mV
# Deviation for threshold 14.000000mV: 0.000090mV
# Deviation for threshold 15.000000mV: 0.000348mV
# Deviation for threshold 16.000000mV: 0.000415mV
# Deviation for threshold 17.000000mV: 0.000434mV
# Deviation for threshold 18.000000mV: 0.000747mV
# Deviation for threshold 19.000000mV: 0.001097mV
# Deviation for threshold 20.000000mV: 0.001163mV
# Deviation for threshold 21.000000mV: 0.001435mV
# Deviation for threshold 22.000000mV: 0.001634mV
# Deviation for threshold 23.000000mV: 0.002135mV
# Deviation for threshold 24.000000mV: 0.001957mV
# Deviation for threshold 25.000000mV: 0.002540mV
# Deviation for threshold 26.000000mV: 0.002936mV
# Deviation for threshold 27.000000mV: 0.003413mV
# Deviation for threshold 28.000000mV: 0.003976mV
# Deviation for threshold 29.000000mV: 0.004955mV
# Deviation for threshold 30.000000mV: 0.005035mV
# Deviation for threshold 31.000000mV: 0.005324mV
# Deviation for threshold 32.000000mV: 0.005438mV
# Deviation for threshold 33.000000mV: 0.006626mV
# Deviation for threshold 34.000000mV: 0.007021mV
# Deviation for threshold 35.000000mV: 0.007591mV
# Size of array: 1
# best threshold: 14.000000
# Best threshold for mpv peak voltage 25mV: 14.000000mV
# Minimum deviation for mpv peak voltage 25: 0.000090
#
# Simulations for mpv peak voltage 35mV
#
# Deviation for threshold 10.000000mV: 0.000376mV
# Deviation for threshold 11.000000mV: 0.000149mV
# Deviation for threshold 12.000000mV: 0.000604mV
# Deviation for threshold 13.000000mV: 0.000409mV
# Deviation for threshold 14.000000mV: 0.000121mV
# Deviation for threshold 15.000000mV: 0.000050mV
# Deviation for threshold 16.000000mV: 0.000088mV
# Deviation for threshold 17.000000mV: 0.000162mV
# Deviation for threshold 18.000000mV: 0.000154mV
# Deviation for threshold 19.000000mV: 0.000262mV
# Deviation for threshold 20.000000mV: 0.000254mV
# Deviation for threshold 21.000000mV: 0.000338mV
# Deviation for threshold 22.000000mV: 0.000514mV
# Deviation for threshold 23.000000mV: 0.000552mV
# Deviation for threshold 24.000000mV: 0.000794mV
# Deviation for threshold 25.000000mV: 0.000889mV
# Deviation for threshold 26.000000mV: 0.001078mV
# Deviation for threshold 27.000000mV: 0.001385mV
# Deviation for threshold 28.000000mV: 0.001432mV
# Deviation for threshold 29.000000mV: 0.001798mV
# Deviation for threshold 30.000000mV: 0.001945mV
# Deviation for threshold 31.000000mV: 0.002166mV
# Deviation for threshold 32.000000mV: 0.002586mV
# Deviation for threshold 33.000000mV: 0.003014mV
# Deviation for threshold 34.000000mV: 0.003610mV
# Deviation for threshold 35.000000mV: 0.003709mV
# Size of array: 1
# best threshold: 15.000000
# Best threshold for mpv peak voltage 35mV: 15.000000mV
# Minimum deviation for mpv peak voltage 35: 0.000050
#
# Simulations for mpv peak voltage 46mV
#
# Deviation for threshold 10.000000mV: 0.000285mV
# Deviation for threshold 11.000000mV: 0.000005mV
# Deviation for threshold 12.000000mV: 0.000218mV
# Deviation for threshold 13.000000mV: 0.000496mV
# Deviation for threshold 14.000000mV: 0.000256mV
# Deviation for threshold 15.000000mV: 0.000118mV
# Deviation for threshold 16.000000mV: 0.000227mV
# Deviation for threshold 17.000000mV: 0.000005mV
# Deviation for threshold 18.000000mV: 0.000039mV
# Deviation for threshold 19.000000mV: 0.000065mV
# Deviation for threshold 20.000000mV: 0.000111mV
# Deviation for threshold 21.000000mV: 0.000129mV
# Deviation for threshold 22.000000mV: 0.000156mV
# Deviation for threshold 23.000000mV: 0.000169mV
# Deviation for threshold 24.000000mV: 0.000241mV
# Deviation for threshold 25.000000mV: 0.000277mV
# Deviation for threshold 26.000000mV: 0.000323mV
# Deviation for threshold 27.000000mV: 0.000524mV
# Deviation for threshold 28.000000mV: 0.000626mV
# Deviation for threshold 29.000000mV: 0.000637mV
# Deviation for threshold 30.000000mV: 0.000876mV
# Deviation for threshold 31.000000mV: 0.001043mV
# Deviation for threshold 32.000000mV: 0.001172mV
# Deviation for threshold 33.000000mV: 0.001155mV
# Deviation for threshold 34.000000mV: 0.001563mV
# Deviation for threshold 35.000000mV: 0.001778mV
# Size of array: 2
# [11. 17.]
# Best threshold for mpv peak voltage 46mV: 14.000000mV
# Minimum deviation for mpv peak voltage 46: 0.000005
#
# Simulations for mpv peak voltage 57mV
#
# Deviation for threshold 10.000000mV: 0.000282mV
# Deviation for threshold 11.000000mV: 0.001017mV
# Deviation for threshold 12.000000mV: 0.000439mV
# Deviation for threshold 13.000000mV: 0.000233mV
# Deviation for threshold 14.000000mV: 0.000019mV
# Deviation for threshold 15.000000mV: 0.000123mV
# Deviation for threshold 16.000000mV: 0.000049mV
# Deviation for threshold 17.000000mV: 0.000054mV
# Deviation for threshold 18.000000mV: 0.000030mV
# Deviation for threshold 19.000000mV: 0.000017mV
# Deviation for threshold 20.000000mV: 0.000050mV
# Deviation for threshold 21.000000mV: 0.000003mV
# Deviation for threshold 22.000000mV: 0.000042mV
# Deviation for threshold 23.000000mV: 0.000038mV
# Deviation for threshold 24.000000mV: 0.000074mV
# Deviation for threshold 25.000000mV: 0.000109mV
# Deviation for threshold 26.000000mV: 0.000144mV
# Deviation for threshold 27.000000mV: 0.000147mV
# Deviation for threshold 28.000000mV: 0.000236mV
# Deviation for threshold 29.000000mV: 0.000212mV
# Deviation for threshold 30.000000mV: 0.000197mV
# Deviation for threshold 31.000000mV: 0.000387mV
# Deviation for threshold 32.000000mV: 0.000427mV
# Deviation for threshold 33.000000mV: 0.000566mV
# Deviation for threshold 34.000000mV: 0.000691mV
# Deviation for threshold 35.000000mV: 0.000732mV
# Size of array: 1
# best threshold: 21.000000
# Best threshold for mpv peak voltage 57mV: 21.000000mV
# Minimum deviation for mpv peak voltage 57: 0.000003
#
# Simulations for mpv peak voltage 67mV
#
# Deviation for threshold 10.000000mV: 0.000205mV
# Deviation for threshold 11.000000mV: 0.000249mV
# Deviation for threshold 12.000000mV: 0.000044mV
# Deviation for threshold 13.000000mV: 0.000092mV
# Deviation for threshold 14.000000mV: 0.000070mV
# Deviation for threshold 15.000000mV: 0.000127mV
# Deviation for threshold 16.000000mV: 0.000025mV
# Deviation for threshold 17.000000mV: 0.000033mV
# Deviation for threshold 18.000000mV: 0.000046mV
# Deviation for threshold 19.000000mV: 0.000055mV
# Deviation for threshold 20.000000mV: 0.000012mV
# Deviation for threshold 21.000000mV: 0.000013mV
# Deviation for threshold 22.000000mV: 0.000022mV
# Deviation for threshold 23.000000mV: 0.000003mV
# Deviation for threshold 24.000000mV: 0.000028mV
# Deviation for threshold 25.000000mV: 0.000033mV
# Deviation for threshold 26.000000mV: 0.000050mV
# Deviation for threshold 27.000000mV: 0.000056mV
# Deviation for threshold 28.000000mV: 0.000072mV
# Deviation for threshold 29.000000mV: 0.000110mV
# Deviation for threshold 30.000000mV: 0.000147mV
# Deviation for threshold 31.000000mV: 0.000176mV
# Deviation for threshold 32.000000mV: 0.000174mV
# Deviation for threshold 33.000000mV: 0.000295mV
# Deviation for threshold 34.000000mV: 0.000295mV
# Deviation for threshold 35.000000mV: 0.000313mV
# Size of array: 1
# best threshold: 23.000000
# Best threshold for mpv peak voltage 67mV: 23.000000mV
# Minimum deviation for mpv peak voltage 67: 0.000003
#
# Simulations for mpv peak voltage 78mV
#
# Deviation for threshold 10.000000mV: 0.000704mV
# Deviation for threshold 11.000000mV: 0.000090mV
# Deviation for threshold 12.000000mV: 0.000167mV
# Deviation for threshold 13.000000mV: 0.000511mV
# Deviation for threshold 14.000000mV: 0.000034mV
# Deviation for threshold 15.000000mV: 0.000132mV
# Deviation for threshold 16.000000mV: 0.000005mV
# Deviation for threshold 17.000000mV: 0.000111mV
# Deviation for threshold 18.000000mV: 0.000019mV
# Deviation for threshold 19.000000mV: 0.000007mV
# Deviation for threshold 20.000000mV: 0.000013mV
# Deviation for threshold 21.000000mV: 0.000007mV
# Deviation for threshold 22.000000mV: 0.000004mV
# Deviation for threshold 23.000000mV: 0.000013mV
# Deviation for threshold 24.000000mV: 0.000020mV
# Deviation for threshold 25.000000mV: 0.000035mV
# Deviation for threshold 26.000000mV: 0.000010mV
# Deviation for threshold 27.000000mV: 0.000006mV
# Deviation for threshold 28.000000mV: 0.000024mV
# Deviation for threshold 29.000000mV: 0.000037mV
# Deviation for threshold 30.000000mV: 0.000034mV
# Deviation for threshold 31.000000mV: 0.000069mV
# Deviation for threshold 32.000000mV: 0.000075mV
# Deviation for threshold 33.000000mV: 0.000128mV
# Deviation for threshold 34.000000mV: 0.000152mV
# Deviation for threshold 35.000000mV: 0.000167mV
# Size of array: 1
# best threshold: 22.000000
# Best threshold for mpv peak voltage 78mV: 22.000000mV
# Minimum deviation for mpv peak voltage 78: 0.000004
#
# Simulations for mpv peak voltage 89mV
#
# Deviation for threshold 10.000000mV: 0.000209mV
# Deviation for threshold 11.000000mV: 0.000630mV
# Deviation for threshold 12.000000mV: 0.000952mV
# Deviation for threshold 13.000000mV: 0.000139mV
# Deviation for threshold 14.000000mV: 0.000062mV
# Deviation for threshold 15.000000mV: 0.000131mV
# Deviation for threshold 16.000000mV: 0.000023mV
# Deviation for threshold 17.000000mV: 0.000036mV
# Deviation for threshold 18.000000mV: 0.000082mV
# Deviation for threshold 19.000000mV: 0.000035mV
# Deviation for threshold 20.000000mV: 0.000002mV
# Deviation for threshold 21.000000mV: 0.000007mV
# Deviation for threshold 22.000000mV: 0.000006mV
# Deviation for threshold 23.000000mV: 0.000019mV
# Deviation for threshold 24.000000mV: 0.000009mV
# Deviation for threshold 25.000000mV: 0.000003mV
# Deviation for threshold 26.000000mV: 0.000006mV
# Deviation for threshold 27.000000mV: 0.000010mV
# Deviation for threshold 28.000000mV: 0.000019mV
# Deviation for threshold 29.000000mV: 0.000013mV
# Deviation for threshold 30.000000mV: 0.000023mV
# Deviation for threshold 31.000000mV: 0.000030mV
# Deviation for threshold 32.000000mV: 0.000041mV
# Deviation for threshold 33.000000mV: 0.000033mV
# Deviation for threshold 34.000000mV: 0.000051mV
# Deviation for threshold 35.000000mV: 0.000070mV
# Size of array: 1
# best threshold: 20.000000
# Best threshold for mpv peak voltage 89mV: 20.000000mV
# Minimum deviation for mpv peak voltage 89: 0.000002
#
# Simulations for mpv peak voltage 100mV
#
# Deviation for threshold 10.000000mV: 0.000462mV
# Deviation for threshold 11.000000mV: 0.000259mV
# Deviation for threshold 12.000000mV: 0.000200mV
# Deviation for threshold 13.000000mV: 0.000054mV
# Deviation for threshold 14.000000mV: 0.000148mV
# Deviation for threshold 15.000000mV: 0.000012mV
# Deviation for threshold 16.000000mV: 0.000058mV
# Deviation for threshold 17.000000mV: 0.000016mV
# Deviation for threshold 18.000000mV: 0.000026mV
# Deviation for threshold 19.000000mV: 0.000027mV
# Deviation for threshold 20.000000mV: 0.000006mV
# Deviation for threshold 21.000000mV: 0.000001mV
# Deviation for threshold 22.000000mV: 0.000013mV
# Deviation for threshold 23.000000mV: 0.000001mV
# Deviation for threshold 24.000000mV: 0.000002mV
# Deviation for threshold 25.000000mV: 0.000003mV
# Deviation for threshold 26.000000mV: 0.000007mV
# Deviation for threshold 27.000000mV: 0.000009mV
# Deviation for threshold 28.000000mV: 0.000003mV
# Deviation for threshold 29.000000mV: 0.000003mV
# Deviation for threshold 30.000000mV: 0.000010mV
# Deviation for threshold 31.000000mV: 0.000021mV
# Deviation for threshold 32.000000mV: 0.000012mV
# Deviation for threshold 33.000000mV: 0.000027mV
# Deviation for threshold 34.000000mV: 0.000034mV
# Deviation for threshold 35.000000mV: 0.000035mV
# Size of array: 2
# [21. 23.]
# Best threshold for mpv peak voltage 100mV: 22.000000mV
# Minimum deviation for mpv peak voltage 100: 0.000001
# CPU time: 929.8336267471313 seconds

# %% [markdown]
# snr = 20 in the beginning
# snr = 5 later
#
# large time window multiple of 3.125
#
# todo later: check non-linear approximation of nr of particles vs mu

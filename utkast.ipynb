# %%
# Import all necessary packages
import ROOT
import numpy as np
# Out:
# Welcome to JupyROOT 6.22/02

# %% [markdown]
# Totala bakgrundsbruset kan beräknas genom formeln
# ![Screenshot%20from%202020-11-12%2010-46-09.png](attachment:Screenshot%20from%202020-11-12%2010-46-09.png)
# Där s<sub>large</sub> är uppmätta signalen från stora fönstret och s<sub>small</sub> är uppmätta signalen från lilla fönstret.

# %% [markdown]
# Totala signalen från "ickebrus" bör alltså vara:
#
# $total noise = s_{large}$
#
# ![Screenshot%20from%202020-11-12%2010-58-59.png](attachment:Screenshot%20from%202020-11-12%2010-58-59.png)
